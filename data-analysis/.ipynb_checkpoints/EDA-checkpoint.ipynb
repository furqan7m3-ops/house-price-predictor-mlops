# %% [markdown]
# # Data Inspection Module

# %%
from analysis.data_inspector import DataInspector, SummaryStatisticsStrategy, DataTypesInspectionStrategy
import pandas as pd

# %%
data_inspector = DataInspector(SummaryStatisticsStrategy())

# %%
dataset_path = './AmesHousing.csv'
df = pd.read_csv(dataset_path)

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %%
data_inspector.execute_inspection(df)
# Out:
# Summary Statistics
# -------------------
# For Numerical Attributes
#             Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     68.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2930.000000   2930.000000  2930.000000     2930.000000   2907.000000
# mean       6.094881      5.563140  1971.356314     1984.266553    101.896801
# ...

# %%
data_inspector.set_strategy(DataTypesInspectionStrategy())

# %%
data_inspector.execute_inspection(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %% [markdown]
# # Missing Value Analyzer Module

# %%
from analysis.missing_value_analysis import MissingValueAnalyzer

# %%
missing_value_analyzer = MissingValueAnalyzer()

# %%
missing_value_analyzer.analyze(df.sample(100))
# Out:
# Identify Missing Values...
# Missing Values Info
# Lot Frontage     22
# Alley            95
# Mas Vnr Type     65
# Mas Vnr Area      1
# Fireplace Qu     48
# Garage Type       4
# Garage Yr Blt     4
# Garage Finish     4
# Garage Qual       4
# Garage Cond       4
# Pool QC          99
# Fence            82
# Misc Feature     94
# dtype: int64

# %%
import importlib
import analysis.missing_value_analysis

# %%
importlib.reload(analysis.missing_value_analysis)
# Out:
# <module 'analysis.missing_value_analysis' from 'D:\\Web Development\\Web Dev Python\\AI Based Web Projects\\House Price Prediction\\data-analysis\\analysis\\missing_value_analysis.py'>

# %% [markdown]
# # Univariate Analysis Module

# %%
from analysis.univariate_analysis import UnivariateAnalyzer, CategoricalUnivariateStrategy, NumericalUnivariateStrategy

# %%
categorical_cols = df.select_dtypes(include='object').columns.to_list()
numerical_cols = df.select_dtypes(exclude='object').columns.to_list()

# %%
categorical_cols
# Out:
# ['MS Zoning',
#  'Street',
#  'Alley',
#  'Lot Shape',
#  'Land Contour',
#  'Utilities',
#  'Lot Config',
#  'Land Slope',
#  'Neighborhood',
#  'Condition 1',
#  'Condition 2',
#  'Bldg Type',
#  'House Style',
#  'Roof Style',
#  'Roof Matl',
#  'Exterior 1st',
#  'Exterior 2nd',
#  'Mas Vnr Type',
#  'Exter Qual',
#  'Exter Cond',
#  'Foundation',
#  'Bsmt Qual',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'BsmtFin Type 1',
#  'BsmtFin Type 2',
#  'Heating',
#  'Heating QC',
#  'Central Air',
#  'Electrical',
#  'Kitchen Qual',
#  'Functional',
#  'Fireplace Qu',
#  'Garage Type',
#  'Garage Finish',
#  'Garage Qual',
#  'Garage Cond',
#  'Paved Drive',
#  'Pool QC',
#  'Fence',
#  'Misc Feature',
#  'Sale Type',
#  'Sale Condition']

# %%
numerical_cols
# Out:
# ['Order',
#  'PID',
#  'MS SubClass',
#  'Lot Frontage',
#  'Lot Area',
#  'Overall Qual',
#  'Overall Cond',
#  'Year Built',
#  'Year Remod/Add',
#  'Mas Vnr Area',
#  'BsmtFin SF 1',
#  'BsmtFin SF 2',
#  'Bsmt Unf SF',
#  'Total Bsmt SF',
#  '1st Flr SF',
#  '2nd Flr SF',
#  'Low Qual Fin SF',
#  'Gr Liv Area',
#  'Bsmt Full Bath',
#  'Bsmt Half Bath',
#  'Full Bath',
#  'Half Bath',
#  'Bedroom AbvGr',
#  'Kitchen AbvGr',
#  'TotRms AbvGrd',
#  'Fireplaces',
#  'Garage Yr Blt',
#  'Garage Cars',
#  'Garage Area',
#  'Wood Deck SF',
#  'Open Porch SF',
#  'Enclosed Porch',
#  '3Ssn Porch',
#  'Screen Porch',
#  'Pool Area',
#  'Misc Val',
#  'Mo Sold',
#  'Yr Sold',
#  'SalePrice']

# %%
univariate_analyzer = UnivariateAnalyzer(NumericalUnivariateStrategy())

# %%
univariate_analyzer.analyze(df, 'Pool Area')

# %%
univariate_analyzer.set_strategy(CategoricalUnivariateStrategy())

# %%
univariate_analyzer.analyze(df, 'Sale Condition')
